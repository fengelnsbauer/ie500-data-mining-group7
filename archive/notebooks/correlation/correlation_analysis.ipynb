# %%
import sys
sys.path.append('../../')

from common.data_preparation import load_and_preprocess_data
import pandas as pd

# Load preprocessed data
df = load_and_preprocess_data()

# Ensure only numeric columns for correlation
numeric_df = df.select_dtypes(include=[float, int])

# Compute correlation of each numeric column with the target 'milliseconds'
corr_with_target = numeric_df.corr(numeric_only=True)['milliseconds'].sort_values(ascending=False)

print("Correlation of features with milliseconds:")
print(corr_with_target)
# Out:
# /Users/I551659/Documents/GitHub/IE650-RAMP/ie500-data-mining-group7/race_simulation/notebooks/correlation
# Index(['resultId', 'raceId', 'driverId', 'constructorId', 'number', 'grid',
#        'position', 'positionText', 'positionOrder', 'points', 'laps', 'time',
#        'racetime_milliseconds', 'fastestLap', 'rank', 'fastestLapTime',
#        'fastestLapSpeed', 'statusId'],
#       dtype='object')
# ...
# Initial data sizes:
# Lap times: (586171, 6)
# ...
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
from ydata_profiling import ProfileReport
import pandas as pd

df = pd.read_csv('data/LAPS.csv')

profile = ProfileReport(df, title="Pandas Profiling Report")
profile.to_file("profile_report.html")

# %% [markdown]
# #### All First Approach Models

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Updating the background color to black explicitly

models = [
    "Baseline",
    "XGB (≥1950) with RS",
    "XGB (≥2003) with RS",
    "XGB (≥2011) with RS",
    "XGB (≥2018) with RS",
    "Stacking Ensemble (without original data) \n (XGB Metaclassifier)",
    "Stacking Ensemble (with original data)\n (RF Metaclassifier)",
]

test_rmse = [4.73, 7.43, 5.58, 4.48, 4.49, 7.62, 5.82]


# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot using Seaborn's barplot
sns.barplot(x=test_rmse, y=models, palette="cool", edgecolor="white", ax=ax)

# Add value annotations
for i, v in enumerate(test_rmse):
    ax.text(v + 0.05, i, f"{v:.2f}", color="white", va="center", fontsize=10)

# Set labels and title
ax.set_xlabel("RMSE", fontsize=12, color="white")
ax.set_ylabel("Models", fontsize=12, color="white")
ax.set_title("RMSE Comparison by Model", fontsize=14, color="white")

# Remove axis borders
for spine in ax.spines.values():
    spine.set_visible(False)

# Customize the axis background and figure background
fig.patch.set_facecolor("black")
ax.set_facecolor("black")

# Adjust gridlines
ax.grid(color="white", linestyle="--", linewidth=0.5, alpha=0.7)

# Customize tick parameters
ax.tick_params(colors="white", labelsize=10)

# Tight layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# /var/folders/zx/63q9k_gd4nb5sbdwq12wb_km0000gn/T/ipykernel_36223/2645277385.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=test_rmse, y=models, palette="cool", edgecolor="white", ax=ax)

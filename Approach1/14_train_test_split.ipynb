# %%
import pandas as pd

full_file_path = '../data/processed/export_combined_v1.csv'
df = pd.read_csv(full_file_path)

df.head()
# Out:
# /var/folders/zx/63q9k_gd4nb5sbdwq12wb_km0000gn/T/ipykernel_14426/1197957614.py:4: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(full_file_path)
#    resultId  raceId  driverId  constructorId number  grid  positionOrder  \
# 0         1      18         1              1     22     1              1
# 1         2      18         2              2      3     5              2
# 2         3      18         3              3      7     7              3
# 3         4      18         4              4      5    11              4
# 4         5      18         5              1     23     3              5
#
#    year  round  circuitId  ... fp2_avg_is_on_fresh_tyres fp3_avg_sector_1  \
# 0  2008      1          1  ...                       NaN              NaN
# 1  2008      1          1  ...                       NaN              NaN
# 2  2008      1          1  ...                       NaN              NaN
# ...

# %%
from sklearn.model_selection import train_test_split

# Define the target variable
y = df["positionOrder"]
X = df.drop(columns=["positionOrder"])

# Perform stratified train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, shuffle=True, random_state=42
)

print(len(X_train[X_train["year"] >= 2018]), len(X_test[X_test["year"] >= 2018]))

# Display the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# 2015 484
# X_train shape: (21359, 80)
# X_test shape: (5340, 80)
# y_train shape: (21359,)
# y_test shape: (5340,)

# %%
import os

# Ensure the directory exists
os.makedirs('../data/train', exist_ok=True)
os.makedirs('../data/test', exist_ok=True)

X_validation.to_csv('../data/validation/validation.csv', index=False)
y_validation.to_csv('../data/validation/validation_labels.csv', index=False)

# Write train data to CSV
X_train.to_csv('../data/train/train.csv', index=False)
y_train.to_csv('../data/train/train_labels.csv', index=False)

# Write test data to CSV
X_test.to_csv('../data/test/test.csv', index=False)
y_test.to_csv('../data/test/test_labels.csv', index=False)
